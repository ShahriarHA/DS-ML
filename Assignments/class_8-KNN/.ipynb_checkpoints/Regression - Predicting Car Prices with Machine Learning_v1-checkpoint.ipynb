# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/rashakil-ds/Public-Datasets/main/automobile.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Goal & Steps:

# %% [markdown]
# 1. Predicting Car Prices:
#    - Task: Build a regression model to predict the price (y=price) of cars based on other features in the dataset. This could involve preprocessing the data, selecting relevant features, and implementing `linear regression` and `KNN` algorithm.
#
# 2. Feature Engineering:
#    - Task: Challenge students to come up with creative ways to engineer new features from the existing ones. For example, they could create a new feature representing the ratio of horsepower to curb weight.
#
# 3. Exploratory Data Analysis (EDA):
#    - Task: Have students perform in-depth exploratory data analysis to understand the relationships between different features. Visualization tools can be used to communicate their findings effectively.
#
# 4. Handling Missing Data:
#    - Task: Teach students how to handle missing data in a dataset. They can explore different strategies such as imputation or removal of missing values.
#
# 5. Training:
#    - Task: Use relavant ML Models
#
# 6. Model evaluation:
# - Evaluate models and Summarizing their findings. This should include a clear explanation of the model's performance and any insights gained from the analysis.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          202 non-null    int64
#  1   normalized-losses  165 non-null    float64
#  2   make               202 non-null    object
#  3   fuel-type          202 non-null    object
#  4   aspiration         202 non-null    object
#  5   num-of-doors       200 non-null    object
#  6   body-style         202 non-null    object
#  7   drive-wheels       202 non-null    object
#  8   engine-location    202 non-null    object
#  9   wheel-base         202 non-null    float64
#  10  length             202 non-null    float64
#  11  width              202 non-null    float64
#  12  height             202 non-null    float64
#  13  curb-weight        202 non-null    int64
#  14  engine-type        202 non-null    object
#  15  num-of-cylinders   202 non-null    object
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# ## spliting dataset

# %%
x = df.drop(["price"],axis=1)

# %%
x.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    num-of-cylinders  engine-size  fuel-system  bore stroke compression-ratio  \
# ...

# %% [markdown]
# ## Handling missing data using Imputation method

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
import numpy as np

# %%
df.replace("?",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
df1 = df.copy()

# %%
import seaborn as sns

# %%
sns.histplot(df["normalized-losses"], kde=True,bins=50)
# Out:
# <Axes: xlabel='normalized-losses', ylabel='Count'>

# %%
normalized_losses_Median = df["normalized-losses"].median()
normalized_losses_Median
# Out:
# 115.0

# %%
df1["normalized-losses"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3      164.0
# 4      164.0
#        ...
# 197     95.0
# 198     95.0
# 199     95.0
# 200     95.0
# 201     95.0
# Name: normalized-losses, Length: 202, dtype: float64

# %%
df["normalized-losses"] = df["normalized-losses"].fillna(normalized_losses_Median)

# %%
df["normalized-losses"]
# Out:
# 0      115.0
# 1      115.0
# 2      115.0
# 3      164.0
# 4      164.0
#        ...
# 197     95.0
# 198     95.0
# 199     95.0
# 200     95.0
# 201     95.0
# Name: normalized-losses, Length: 202, dtype: float64

# %%
df1["num-of-doors"][26:30]
# Out:
# 26     NaN
# 27    four
# 28     two
# 29     two
# Name: num-of-doors, dtype: object

# %%
df1["num-of-doors"][60:65]
# Out:
# 60     NaN
# 61    four
# 62    four
# 63    four
# 64    four
# Name: num-of-doors, dtype: object

# %%
num_of_doors_mode = df["num-of-doors"].mode()[0]
num_of_doors_mode
# Out:
# 'four'

# %%
df["num-of-doors"] = df["num-of-doors"].fillna(num_of_doors_mode)

# %%
df["num-of-doors"][26:30]
# Out:
# 26    four
# 27    four
# 28     two
# 29     two
# Name: num-of-doors, dtype: object

# %%
df["num-of-doors"][60:65]
# Out:
# 60    four
# 61    four
# 62    four
# 63    four
# 64    four
# Name: num-of-doors, dtype: object

# %%
df["bore"]
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 197    3.78
# 198    3.58
# 199    3.01
# 200    3.78
# 201    3.78
# Name: bore, Length: 202, dtype: object

# %%
df["bore"] = df["bore"].astype(float)

# %%
df["bore"]
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 197    3.78
# 198    3.58
# 199    3.01
# 200    3.78
# 201    3.78
# Name: bore, Length: 202, dtype: float64

# %%
df1["bore"][51:60]
# Out:
# 51    3.08
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56    3.39
# 57    3.39
# 58    3.39
# 59    3.39
# Name: bore, dtype: object

# %%
sns.histplot(df["bore"], kde=True,bins=50)
# Out:
# <Axes: xlabel='bore', ylabel='Count'>

# %%
bore_Median = df["bore"].median()
bore_Median
# Out:
# 3.31

# %%
df["bore"] = df["bore"].fillna(bore_Median)

# %%
df["bore"][51:60]
# Out:
# 51    3.08
# 52    3.31
# 53    3.31
# 54    3.31
# 55    3.31
# 56    3.39
# 57    3.39
# 58    3.39
# 59    3.39
# Name: bore, dtype: float64

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df1["stroke"][51:60]
# Out:
# 51    3.15
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56    3.39
# 57    3.39
# 58    3.39
# 59    3.39
# Name: stroke, dtype: object

# %%
df["stroke"] = df["stroke"].astype(float)

# %%
df["stroke"][51:60]
# Out:
# 51    3.15
# 52     NaN
# 53     NaN
# 54     NaN
# 55     NaN
# 56    3.39
# 57    3.39
# 58    3.39
# 59    3.39
# Name: stroke, dtype: float64

# %%
sns.histplot(df["stroke"], kde=True,bins=50)
# Out:
# <Axes: xlabel='stroke', ylabel='Count'>

# %%
stroke_Median = df["stroke"].median()
stroke_Median
# Out:
# 3.29

# %%
df["stroke"] = df["stroke"].fillna(stroke_Median)

# %%
df["stroke"][51:60]
# Out:
# 51    3.15
# 52    3.29
# 53    3.29
# 54    3.29
# 55    3.29
# 56    3.39
# 57    3.39
# 58    3.39
# 59    3.39
# Name: stroke, dtype: float64

# %%
df["horsepower"] = df["horsepower"].astype("Int64")

# %%
df["horsepower"][124:130]
# Out:
# 124     207
# 125     207
# 126    <NA>
# 127    <NA>
# 128     110
# 129     110
# Name: horsepower, dtype: Int64

# %%
sns.histplot(df["horsepower"], kde=True,bins=50)
# Out:
# <Axes: xlabel='horsepower', ylabel='Count'>

# %%
HP_Median = df["horsepower"].median()
HP_Median
# Out:
# np.float64(95.0)

# %%
HP_Median = int(HP_Median)
HP_Median
# Out:
# 95

# %%
df["horsepower"] = df["horsepower"].fillna(HP_Median)

# %%
df["horsepower"][124:130]
# Out:
# 124    207
# 125    207
# 126     95
# 127     95
# 128    110
# 129    110
# Name: horsepower, dtype: Int64

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df["peak-rpm"][124:130]
# Out:
# 124    5900
# 125    5900
# 126     NaN
# 127     NaN
# 128    5250
# 129    5250
# Name: peak-rpm, dtype: object

# %%
df["peak-rpm"] = df["peak-rpm"].astype("Int64")

# %%
df["peak-rpm"][124:130]
# Out:
# 124    5900
# 125    5900
# 126    <NA>
# 127    <NA>
# 128    5250
# 129    5250
# Name: peak-rpm, dtype: Int64

# %%
sns.histplot(df["peak-rpm"], kde=True,bins=50)
# Out:
# <Axes: xlabel='peak-rpm', ylabel='Count'>

# %%
prpm_Median = df["peak-rpm"].median()
prpm_Median
# Out:
# np.float64(5200.0)

# %%
prpm_Median = int(prpm_Median)
prpm_Median
# Out:
# 5200

# %%
df["peak-rpm"] = df["peak-rpm"].fillna(prpm_Median)

# %%
df["peak-rpm"][124:130]
# Out:
# 124    5900
# 125    5900
# 126    5200
# 127    5200
# 128    5250
# 129    5250
# Name: peak-rpm, dtype: Int64

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower             Int64
# peak-rpm               Int64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %% [markdown]
# ## One hot encoding for make coloumn

# %%
# for make Column
dummy_make = pd.get_dummies(df['make'], drop_first=True, prefix='make', prefix_sep=' ')

# %%
dummy_make
# Out:
#      make audi  make bmw  make chevrolet  make dodge  make honda  make isuzu  \
# 0        False     False           False       False       False       False
# 1        False     False           False       False       False       False
# 2        False     False           False       False       False       False
# 3         True     False           False       False       False       False
# 4         True     False           False       False       False       False
# ..         ...       ...             ...         ...         ...         ...
# 197      False     False           False       False       False       False
# 198      False     False           False       False       False       False
# 199      False     False           False       False       False       False
# 200      False     False           False       False       False       False
# 201      False     False           False       False       False       False
#
# ...

# %%
df.drop("make",axis=1,inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses fuel-type aspiration num-of-doors  \
# 0          3              115.0       gas        std          two
# 1          3              115.0       gas        std          two
# 2          1              115.0       gas        std          two
# 3          2              164.0       gas        std         four
# 4          2              164.0       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    engine-size  fuel-system  bore stroke compression-ratio  horsepower  \
# 0          130         mpfi  3.47   2.68               9.0         111
# ...

# %%
df = pd.concat([df,dummy_make],axis=1)

# %%
df.head()
# Out:
#    symboling  normalized-losses fuel-type aspiration num-of-doors  \
# 0          3              115.0       gas        std          two
# 1          3              115.0       gas        std          two
# 2          1              115.0       gas        std          two
# 3          2              164.0       gas        std         four
# 4          2              164.0       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    make nissan  make peugot  make plymouth make porsche make renault  \
# 0        False        False          False        False        False
# ...

# %% [markdown]
# ## Label encoding for fuel-type and aspiration column

# %%
df["fuel-type"] = df["fuel-type"].map({"gas":0,"diesel":1})

# %%
df[103:110]
# Out:
#      symboling  normalized-losses  fuel-type aspiration num-of-doors  \
# 103          1              231.0          0        std          two
# 104          0              161.0          0        std         four
# 105          0              161.0          1      turbo         four
# 106          0              115.0          0        std         four
# 107          0              115.0          1      turbo         four
# 108          0              161.0          0        std         four
# 109          0              161.0          1      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 103  hatchback          rwd           front        99.2   178.5  ...
# 104      sedan          rwd           front       107.9   186.7  ...
# 105      sedan          rwd           front       107.9   186.7  ...
# 106      wagon          rwd           front       114.2   198.9  ...
# ...

# %%
df["aspiration"] = df["aspiration"].map({"std":0,"turbo":1})

# %%
df[20:32]
# Out:
#     symboling  normalized-losses  fuel-type  aspiration num-of-doors  \
# 20          1              118.0          0           0          two
# 21          1              118.0          0           0          two
# 22          1              118.0          0           1          two
# 23          1              148.0          0           0         four
# 24          1              148.0          0           0         four
# 25          1              148.0          0           0         four
# 26          1              148.0          0           1         four
# 27         -1              110.0          0           0         four
# 28          3              145.0          0           1          two
# 29          2              137.0          0           0          two
# 30          2              137.0          0           0          two
# 31          1              101.0          0           0          two
#
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses  fuel-type  aspiration num-of-doors  \
# 0          3              115.0          0           0          two
# 1          3              115.0          0           0          two
# 2          1              115.0          0           0          two
# 3          2              164.0          0           0         four
# 4          2              164.0          0           0         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    make nissan  make peugot  make plymouth make porsche make renault  \
# ...

# %% [markdown]
# ### label encoding for num-of-doors

# %%
df["num-of-doors"].unique()
# Out:
# array(['two', 'four'], dtype=object)

# %%
df["num-of-doors"] = df["num-of-doors"].map({"two":0,"four":1})

# %%
df[:15]
# Out:
#     symboling  normalized-losses  fuel-type  aspiration  num-of-doors  \
# 0           3              115.0          0           0             0
# 1           3              115.0          0           0             0
# 2           1              115.0          0           0             0
# 3           2              164.0          0           0             1
# 4           2              164.0          0           0             1
# 5           2              115.0          0           0             0
# 6           1              158.0          0           0             1
# 7           1              115.0          0           0             1
# 8           1              158.0          0           1             1
# 9           2              192.0          0           0             0
# 10          0              192.0          0           0             1
# 11          0              188.0          0           0             0
# ...

# %% [markdown]
# ### One-hot encoding for body-style column

# %%
df["body-style"].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
dummy_body_style = pd.get_dummies(df['body-style'], drop_first=True, prefix='Body-Style', prefix_sep=' ')

# %%
df.drop("body-style",axis=1,inplace=True)

# %%
df = pd.concat([df,dummy_body_style],axis=1)

# %%
dummy_body_style.dtypes
# Out:
# Body-Style hardtop      bool
# Body-Style hatchback    bool
# Body-Style sedan        bool
# Body-Style wagon        bool
# dtype: object

# %% [markdown]
# ### One-hot encoding for drive-wheels columns

# %%
df["drive-wheels"].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
dummy_drive_wheels = pd.get_dummies(df['drive-wheels'], drop_first=True, prefix='drive-wheels', prefix_sep=' ')

# %%
df.drop("drive-wheels",axis=1,inplace=True)

# %%
df = pd.concat([df,dummy_drive_wheels],axis=1)

# %%
dummy_drive_wheels.dtypes
# Out:
# drive-wheels fwd    bool
# drive-wheels rwd    bool
# dtype: object

# %% [markdown]
# ### label encoding for engine-location column

# %%
df["engine-location"].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
df["engine-location"] = df["engine-location"].map({"front":0,"rear":1})

# %%
df["engine-location"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 197    0
# 198    0
# 199    0
# 200    0
# 201    0
# Name: engine-location, Length: 202, dtype: int64

# %%
df
# Out:
#      symboling  normalized-losses  fuel-type  aspiration  num-of-doors  \
# 0            3              115.0          0           0             0
# 1            3              115.0          0           0             0
# 2            1              115.0          0           0             0
# 3            2              164.0          0           0             1
# 4            2              164.0          0           0             1
# ..         ...                ...        ...         ...           ...
# 197         -1               95.0          0           1             1
# 198         -1               95.0          0           0             1
# 199         -1               95.0          1           1             1
# 200         -1               95.0          0           1             1
# 201         -1               95.0          0           1             1
#
#      engine-location  wheel-base  length  width  height  ...  make subaru  \
# ...

# %%
df.dtypes
# Out:
# symboling                 int64
# normalized-losses       float64
# fuel-type                 int64
# aspiration                int64
# num-of-doors              int64
# engine-location           int64
# wheel-base              float64
# length                  float64
# width                   float64
# height                  float64
# curb-weight               int64
# engine-type              object
# num-of-cylinders         object
# engine-size               int64
# fuel-system              object
# bore                    float64
# stroke                  float64
# compression-ratio       float64
# horsepower                Int64
# peak-rpm                  Int64
# city-mpg                  int64
# highway-mpg               int64
# price                     int64
# make audi                  bool
# make bmw                   bool
# make chevrolet             bool
# make dodge                 bool
# make honda                 bool
# make isuzu                 bool
# ...

# %% [markdown]
# ### One-hot encoding for engine-type column

# %%
df["engine-type"].unique()
# Out:
# array(['dohc', 'ohcv', 'ohc', 'l', 'rotor', 'ohcf'], dtype=object)

# %%
dummy_engine_type = pd.get_dummies(df['engine-type'], drop_first=True, prefix='engine-type', prefix_sep=' ')

# %%
df.drop("engine-type",axis=1,inplace=True)

# %%
dummy_engine_type
# Out:
#      engine-type l  engine-type ohc  engine-type ohcf  engine-type ohcv  \
# 0            False            False             False             False
# 1            False            False             False             False
# 2            False            False             False              True
# 3            False             True             False             False
# 4            False             True             False             False
# ..             ...              ...               ...               ...
# 197          False             True             False             False
# 198          False            False             False              True
# 199          False             True             False             False
# 200          False             True             False             False
# 201          False             True             False             False
#
#      engine-type rotor
# 0                False
# 1                False
# 2                False
# ...

# %%
df = pd.concat([df,dummy_engine_type],axis=1)

# %% [markdown]
# ### encoding for num-of-cylinders column

# %%
df["num-of-cylinders"].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
cyl = {
    "four": 4,
    "six": 6,
    "five": 5,
    "three": 3,
    "twelve":12,
    "two": 2,
    "eight": 8
}

# %%
type(cyl)
# Out:
# dict

# %%
df["num-of-cylinders"] = df["num-of-cylinders"].map(cyl)

# %%
df["num-of-cylinders"]
# Out:
# 0      4
# 1      4
# 2      6
# 3      4
# 4      5
#       ..
# 197    4
# 198    6
# 199    6
# 200    4
# 201    4
# Name: num-of-cylinders, Length: 202, dtype: int64

# %% [markdown]
# ### one-hot encoding for fuel-system column

# %%
dummy_fuel_system = pd.get_dummies(df['fuel-system'], drop_first=True, prefix='fuel-system', prefix_sep=' ')

# %%
dummy_fuel_system
# Out:
#      fuel-system 2bbl  fuel-system 4bbl  fuel-system idi  fuel-system mfi  \
# 0               False             False            False            False
# 1               False             False            False            False
# 2               False             False            False            False
# 3               False             False            False            False
# 4               False             False            False            False
# ..                ...               ...              ...              ...
# 197             False             False            False            False
# 198             False             False            False            False
# 199             False             False             True            False
# 200             False             False            False            False
# 201             False             False            False            False
#
#      fuel-system mpfi  fuel-system spdi  fuel-system spfi
# ...

# %%
df.drop("fuel-system",axis=1,inplace=True)

# %%
df = pd.concat([df,dummy_fuel_system],axis=1)

# %% [markdown]
# ## new feature representing ratio of horspower to curb weight

# %%
df[20:50]
# Out:
#     symboling  normalized-losses  fuel-type  aspiration  num-of-doors  \
# 20          1              118.0          0           0             0
# 21          1              118.0          0           0             0
# 22          1              118.0          0           1             0
# 23          1              148.0          0           0             1
# 24          1              148.0          0           0             1
# 25          1              148.0          0           0             1
# 26          1              148.0          0           1             1
# 27         -1              110.0          0           0             1
# 28          3              145.0          0           1             0
# 29          2              137.0          0           0             0
# 30          2              137.0          0           0             0
# 31          1              101.0          0           0             0
# ...

# %%
df["horsepower_curbWeight"] = df["horsepower"] / df["curb-weight"]

# %%
df[0:20]
# Out:
#     symboling  normalized-losses  fuel-type  aspiration  num-of-doors  \
# 0           3              115.0          0           0             0
# 1           3              115.0          0           0             0
# 2           1              115.0          0           0             0
# 3           2              164.0          0           0             1
# 4           2              164.0          0           0             1
# 5           2              115.0          0           0             0
# 6           1              158.0          0           0             1
# 7           1              115.0          0           0             1
# 8           1              158.0          0           1             1
# 9           2              192.0          0           0             0
# 10          0              192.0          0           0             1
# 11          0              188.0          0           0             0
# ...

# %%
df["horsepower_curbWeight"]
# Out:
# 0      0.043564
# 1      0.043564
# 2      0.054552
# 3      0.043646
# 4      0.040722
#          ...
# 197    0.052476
# 198    0.044489
# 199     0.03295
# 200    0.037231
# 201    0.037231
# Name: horsepower_curbWeight, Length: 202, dtype: Float64

# %% [markdown]
# ## Linear Regression and KNN regression implimentation

# %%
x = df.drop("price",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 x = df.drop("price",axis=1)
#
# File ~/Software/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...
