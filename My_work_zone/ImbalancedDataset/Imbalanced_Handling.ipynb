# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = df = pd.read_csv(r"D:\Courses\DS&ML\Class_07-LogisticRegression&ImbalancedDataset\Customer-Churn-Prediction.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop("Churn",axis=1)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
y = df.Churn

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: Churn
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 55.2+ KB

# %%
y.head()
# Out:
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# Name: Churn, dtype: object

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.30,random_state=42)

# %%
xtrain.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1695  4906-ZHGPK    Male              0     Yes        Yes      54
# 1095  7439-DKZTW    Male              0      No         No       1
# 3889  2592-HODOV    Male              0      No         No      13
# 3667  7826-VVKWT  Female              1     Yes        Yes      24
# 2902  1658-TJVOA  Female              1      No         No       6
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 1695          Yes           Yes             DSL                   No
# 1095          Yes            No     Fiber optic                   No
# 3889          Yes            No              No  No internet service
# 3667          Yes            No     Fiber optic                   No
# 2902          Yes            No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 1695                  Yes                   No                  Yes
# ...

# %%
ytrain.head()
# Out:
# 1695    No
# 1095    No
# 3889    No
# 3667    No
# 2902    No
# Name: Churn, dtype: object

# %%
print(xtrain.shape,ytrain.shape)
# Out:
# (4930, 20) (4930,)

# %% [markdown]
# ## label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
ytrain_pre = le.fit_transform(ytrain)
ytest_pre = le.transform(ytest)

# %%
ytrain_pre
# Out:
# array([0, 0, 0, ..., 0, 1, 0], shape=(4930,))

# %%
ytest_pre
# Out:
# array([1, 0, 0, ..., 0, 0, 0], shape=(2113,))

# %%
xtrain.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges'],
#       dtype='object')

# %%
from pandas.api.types import is_numeric_dtype

# %%
numeric_columns = [col for col in xtrain.columns if is_numeric_dtype(xtrain[col])]

# %%
numeric_columns
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges']

# %%
categorical_columns = [col for col in xtrain.columns if not is_numeric_dtype(xtrain[col])]

# %%
categorical_columns
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges']

# %%
xtrain.customerID.unique()
# Out:
# array(['4906-ZHGPK', '7439-DKZTW', '2592-HODOV', ..., '8044-BGWPI',
#        '7450-NWRTR', '4795-UXVCJ'], shape=(4930,), dtype=object)

# %%
xtrain.shape
# Out:
# (4930, 20)

# %%
xtest.shape
# Out:
# (2113, 20)

# %%
xtrain = xtrain.drop(columns="customerID")
xtest = xtest.drop(columns="customerID")

# %%
xtrain.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1695    Male              0     Yes        Yes      54          Yes
# 1095    Male              0      No         No       1          Yes
# 3889    Male              0      No         No      13          Yes
# 3667  Female              1     Yes        Yes      24          Yes
# 2902  Female              1      No         No       6          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 1695           Yes             DSL                   No                  Yes
# 1095            No     Fiber optic                   No                   No
# 3889            No              No  No internet service  No internet service
# 3667            No     Fiber optic                   No                   No
# 2902            No     Fiber optic                  Yes                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
xtest.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 185   Female              0     Yes         No       1           No
# 2715    Male              0      No         No      41          Yes
# 3825  Female              0     Yes        Yes      52          Yes
# 1807  Female              0      No         No       1          Yes
# 132     Male              0      No         No      67          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 185   No phone service             DSL                   No
# 2715               Yes              No  No internet service
# 3825                No              No  No internet service
# 1807                No     Fiber optic                   No
# 132                 No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 185                    No                   No                   No
# ...

# %%
categorical_columns
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'TotalCharges']

# %%
xtrain.TotalCharges.value_counts()
# Out:
# TotalCharges
# 19.75      8
#            8
# 20.2       7
# 19.9       6
# 19.55      6
#           ..
# 95         1
# 2198.3     1
# 306.05     1
# 1200.15    1
# 144.15     1
# Name: count, Length: 4660, dtype: int64

# %%
xtrain.TotalCharges.unique()
# Out:
# array(['3770', '80.55', '259.65', ..., '306.05', '1200.15', '457.3'],
#       shape=(4660,), dtype=object)

# %%
xtrain['TotalCharges'] = pd.to_numeric(xtrain.TotalCharges,errors='coerce')
xtest['TotalCharges'] = pd.to_numeric(xtest.TotalCharges,errors='coerce')

# %%
xtrain.TotalCharges.isnull().sum()
# Out:
# np.int64(8)

# %%
xtrain.TotalCharges.fillna(xtrain.TotalCharges.median(),inplace=True)
xtest.TotalCharges.fillna(xtest.TotalCharges.median(),inplace=True)

# %%
ordinal_en_columns = ['gender','Partner','Dependents','PhoneService','Contract','PaperlessBilling']

# %%
one_hoten_columns = ['MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection',
                     'TechSupport','StreamingTV','StreamingMovies','PaymentMethod']

# %%
xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4930 entries, 1695 to 860
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            4930 non-null   object
#  1   SeniorCitizen     4930 non-null   int64
#  2   Partner           4930 non-null   object
#  3   Dependents        4930 non-null   object
#  4   tenure            4930 non-null   int64
#  5   PhoneService      4930 non-null   object
#  6   MultipleLines     4930 non-null   object
#  7   InternetService   4930 non-null   object
#  8   OnlineSecurity    4930 non-null   object
#  9   OnlineBackup      4930 non-null   object
#  10  DeviceProtection  4930 non-null   object
#  11  TechSupport       4930 non-null   object
#  12  StreamingTV       4930 non-null   object
#  13  StreamingMovies   4930 non-null   object
#  14  Contract          4930 non-null   object
#  15  PaperlessBilling  4930 non-null   object
# ...

# %%
df.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('ont_hot',OneHotEncoder(handle_unknown='ignore'),one_hoten_columns),
        ('ordinal',OrdinalEncoder(),ordinal_en_columns)
    ]
)

# %%
models = {
    "LogisticRegression": LogisticRegression(),
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "KNeighborsClassifier": KNeighborsClassifier()
}

# %%
for name,model in models.items():
    # print(name,model)
    clf = Pipeline(steps=[
        ("preprocessor", preprocessor),
        ("smote",SMOTE()),
        ("model",model)
    ])
    clf.fit(xtrain,ytrain)
    clf.predict(xtest)
    print(f"Training score is, {name}: {clf.score(xtrain,ytrain)}")
    print(f"test score is, {name}: {clf.score(xtest,ytest)}")
# Out:
# Training score is, LogisticRegression: 0.7304259634888438
# test score is, LogisticRegression: 0.738760056791292
# Training score is, DecisionTreeClassifier: 0.9127789046653144
# test score is, DecisionTreeClassifier: 0.7307146237576905
# Training score is, KNeighborsClassifier: 0.8008113590263691
# test score is, KNeighborsClassifier: 0.6914339801230478
